# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
weather = pd.read_csv("data.csv")

# %%
weather
# Out:
#     Perspectiva  Temperatura  Humedad  Viento  Jugar
# 0             1         29.0       85   False  False
# 1             1         27.0       90    True  False
# 2             0         28.0       86   False   True
# 3            -1         21.0       96   False   True
# 4            -1         20.0       80   False   True
# 5            -1         18.0       70    True  False
# 6             0         17.0       65    True   True
# 7             1         22.0       95   False  False
# 8             1         20.5       70   False   True
# 9            -1         24.0       80   False   True
# 10            1         24.0       70    True   True
# 11            0         22.0       90    True   True
# 12            0         27.0       75   False   True
# 13           -1         21.6       91    True  False

# %%
weather.columns.values
# Out:
# array(['Perspectiva', 'Temperatura', 'Humedad', 'Viento', 'Jugar'],
#       dtype=object)

# %%
feature_cols = ["Perspectiva", "Temperatura", "Humedad", "Viento"]
X = weather[feature_cols] # Features
Y = weather["Jugar"] # Target variable

# %%
X
# Out:
#     Perspectiva  Temperatura  Humedad  Viento
# 0             1         29.0       85   False
# 1             1         27.0       90    True
# 2             0         28.0       86   False
# 3            -1         21.0       96   False
# 4            -1         20.0       80   False
# 5            -1         18.0       70    True
# 6             0         17.0       65    True
# 7             1         22.0       95   False
# 8             1         20.5       70   False
# 9            -1         24.0       80   False
# 10            1         24.0       70    True
# 11            0         22.0       90    True
# 12            0         27.0       75   False
# 13           -1         21.6       91    True

# %%
Y
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7     False
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# Name: Jugar, dtype: bool

# %%
clf = DecisionTreeClassifier(max_depth=2)
clf = clf.fit(X,Y)

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('weather.png')
Image(graph.create_png())
